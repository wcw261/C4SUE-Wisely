# %% [markdown]
# ## Class 10
# ## Plotting Points data: 311 data 📲 📲 📲 📲
#
# c4sue 2021 NYU @avigailvantu
#
# Today we will continue to work with Pandas and Matplotlib. We will also create some maps using geopandas. Looking into 311 complaints from the past month and from the same period in 2021 we will compare, group and visualize the city’s trends. Along the way we will create a GeoDataFrame, this is a geographical format that is similar enough to a data frame but has an extra dimension of geographical attributes to it.  Think of the times where we loaded a CSV data into QGIS and needed to merge with a swapfile of assign column to a geographical unit.
#
# This week we will be doing something similar, only with that we will transform a csv (which we will read into a data frame) and then assign columns in the data to represent geometry. That would enable us to then visualize the data quite easily. We’ll some pretty simple, yet cool, ways to do so!

# %% [markdown]
# ## Installing GeoPandas:
#
# Before getting started with today's class you will need to download the GeoPandas library (in case you don't have it already). The easiest way is to follow the intructions on the library page:
#
# https://geopandas.org/getting_started.html
#
# If you are facing issues installing through Codna you can create a new enviorment. There are some details about it on the GeoPandas page. In addition, there are more instructions inside the "class 10" folder on Github.
#
# https://github.com/avigailvantu/c4sue2021/tree/main/labs/class_10

# %%
pip install geopandas
# Out:
# Requirement already satisfied: geopandas in /opt/anaconda3/lib/python3.8/site-packages (0.9.0)
# Requirement already satisfied: fiona>=1.8 in /opt/anaconda3/lib/python3.8/site-packages (from geopandas) (1.8.19)
# Requirement already satisfied: pandas>=0.24.0 in /opt/anaconda3/lib/python3.8/site-packages (from geopandas) (1.1.3)
# Requirement already satisfied: shapely>=1.6 in /opt/anaconda3/lib/python3.8/site-packages (from geopandas) (1.7.1)
# Requirement already satisfied: pyproj>=2.2.0 in /opt/anaconda3/lib/python3.8/site-packages (from geopandas) (3.0.1)
# Requirement already satisfied: munch in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: cligj>=0.5 in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (0.7.1)
# Requirement already satisfied: click<8,>=4.0 in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: attrs>=17 in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (20.3.0)
# Requirement already satisfied: click-plugins>=1.0 in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2020.6.20)
# Requirement already satisfied: six>=1.7 in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: pytz>=2017.2 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.0->geopandas) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.0->geopandas) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.0->geopandas) (1.19.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import geopandas as gpd 
import matplotlib 
import matplotlib.pyplot as plt
#from shapely.geometry import Point
#from geopandas import GeoDataFrame

# %% [markdown]
# For this assignment I downloaded the 311 data from the NYC Open Data platform. I wanted to look into how people in the city complaint patterns were in the past month. In order to get a relative understating we will compare data from 2020 and 2021. Comparing similar periods in between years is a common method in highlighting changes and trends. Thinking about time series, many phenomenas are seasonal. Which is why comparing one month to the previous month is tricky. Having said that, even the same period in two separate years is likely to have some differences, but hopefully less.
#
#
# - Data 2020: March 1st - March 31st 2020
# - Data 2021: March 1st - March 31st 2021
#
# * Note: you will need to fetch the data yourself from the NYC Open Data Flatrform

# %%
#load 311 data 1 for this year and one for last year: 
data20 = pd.read_csv('311_March2020.csv')
data21 = pd.read_csv('311_March2021.csv')

#load 2020 data
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (20,31) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data20.head(5)
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    45727718  03/01/2020 12:00:00 AM  03/02/2020 10:37:56 AM  DOHMH
# 1    45730477  03/01/2020 12:00:00 AM  03/02/2020 12:00:01 AM  DOHMH
# 2    45731136  03/01/2020 12:00:00 AM  03/09/2020 12:00:01 AM  DOHMH
# 3    45731855  03/01/2020 12:00:00 AM  03/02/2020 10:19:39 AM  DOHMH
# 4    45728413  03/01/2020 12:00:00 AM  03/02/2020 12:00:01 AM  DOHMH
#
#                                Agency Name  Complaint Type Descriptor  \
# 0  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 1  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 2  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 3  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 4  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
#
#                 Location Type  Incident Zip     Incident Address  ...  \
# 0  Restaurant/Bar/Deli/Bakery       10468.0    2297 CEDAR AVENUE  ...
# 1  Restaurant/Bar/Deli/Bakery       10468.0    2297 CEDAR AVENUE  ...
# 2  Restaurant/Bar/Deli/Bakery       11691.0    20-17 MOTT AVENUE  ...
# 3  Restaurant/Bar/Deli/Bakery       10458.0  2954 WEBSTER AVENUE  ...
# 4  Restaurant/Bar/Deli/Bakery       10128.0        1570 3 AVENUE  ...
#
#   Vehicle Type Taxi Company Borough Taxi Pick Up Location Bridge Highway Name  \
# 0          NaN                  NaN                   NaN                 NaN
# 1          NaN                  NaN                   NaN                 NaN
# 2          NaN                  NaN                   NaN                 NaN
# 3          NaN                  NaN                   NaN                 NaN
# 4          NaN                  NaN                   NaN                 NaN
#
#   Bridge Highway Direction Road Ramp Bridge Highway Segment   Latitude  \
# 0                      NaN       NaN                    NaN  40.862225
# 1                      NaN       NaN                    NaN  40.862225
# 2                      NaN       NaN                    NaN  40.604333
# 3                      NaN       NaN                    NaN  40.867391
# 4                      NaN       NaN                    NaN  40.780279
#
#    Longitude                                 Location
# 0 -73.911159  (40.86222535202683, -73.91115884964748)
# 1 -73.911159  (40.86222535202683, -73.91115884964748)
# 2 -73.753038  (40.60433339241671, -73.75303800188094)
# 3 -73.883392  (40.867390857417874, -73.8833918894606)
# 4 -73.952933  (40.78027896232064, -73.95293321926803)
#
# [5 rows x 41 columns]

# %%
data21.head(5)
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    49892855  03/01/2021 12:00:00 AM  03/01/2021 12:00:01 AM  DOHMH
# 1    49897552  03/01/2021 12:00:00 AM  03/01/2021 12:00:01 AM  DOHMH
# 2    49898355  03/01/2021 12:00:00 AM  03/08/2021 10:57:21 AM  DOHMH
# 3    49899122  03/01/2021 12:00:00 AM  03/09/2021 12:00:01 AM  DOHMH
# 4    49902850  03/01/2021 12:00:00 AM  03/01/2021 11:04:02 AM  DOHMH
#
#                                Agency Name  Complaint Type Descriptor  \
# 0  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 1  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 2  Department of Health and Mental Hygiene  Food Poisoning  3 or More
# 3  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 4  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
#
#                 Location Type  Incident Zip            Incident Address  ...  \
# 0  Restaurant/Bar/Deli/Bakery       10467.0       89 EAST GUN HILL ROAD  ...
# 1  Restaurant/Bar/Deli/Bakery       11211.0  145 GRAND STREET EXTENSION  ...
# 2  Restaurant/Bar/Deli/Bakery       10475.0          2160 BARTOW AVENUE  ...
# 3  Restaurant/Bar/Deli/Bakery       10039.0                    7 AVENUE  ...
# 4  Restaurant/Bar/Deli/Bakery       11211.0       200 NORTH   11 STREET  ...
#
#   Vehicle Type Taxi Company Borough Taxi Pick Up Location Bridge Highway Name  \
# 0          NaN                  NaN                   NaN                 NaN
# 1          NaN                  NaN                   NaN                 NaN
# 2          NaN                  NaN                   NaN                 NaN
# 3          NaN                  NaN                   NaN                 NaN
# 4          NaN                  NaN                   NaN                 NaN
#
#   Bridge Highway Direction Road Ramp Bridge Highway Segment   Latitude  \
# 0                      NaN       NaN                    NaN  40.881706
# 1                      NaN       NaN                    NaN  40.710662
# 2                      NaN       NaN                    NaN  40.869329
# 3                      NaN       NaN                    NaN  40.823567
# 4                      NaN       NaN                    NaN  40.718995
#
#    Longitude                                  Location
# 0 -73.879646  (40.881706083225524, -73.87964559673972)
# 1 -73.954180   (40.71066163433815, -73.95417991036442)
# 2 -73.825126    (40.86932913143279, -73.8251260589038)
# 3 -73.937673   (40.82356703878467, -73.93767317525372)
# 4 -73.953673  (40.718994526951334, -73.95367274183664)
#
# [5 rows x 41 columns]

# %%
print ('shape 2020',data20.shape)
print ('shape 2021',data21.shape)
# Out:
# shape 2020 (153166, 41)
# shape 2021 (204771, 41)

# %% [markdown]
# ### Question 1:
# What are the changes between 2020 and 2021 data in terms of quantities of non emargency complaints in NYC?

# %%
#What are the columns in the data? 
print ('2020 columns:',data20.columns)
print ('2021 columns:',data21.columns)
# Out:
# 2020 columns: Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'BBL', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Open Data Channel Type',
#        'Park Facility Name', 'Park Borough', 'Vehicle Type',
#        'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name',
#        'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment',
#        'Latitude', 'Longitude', 'Location'],
#       dtype='object')
# 2021 columns: Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'BBL', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Open Data Channel Type',
#        'Park Facility Name', 'Park Borough', 'Vehicle Type',
#        'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name',
#        'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment',
#        'Latitude', 'Longitude', 'Location'],
#       dtype='object')

# %% [markdown]
# # 311 data for 2020 and 2021 data by agency:
#
# Let's look into the "value_counts" function. That would return the number of values for each value in the Agencey column. Meaning we will get a list of how many complaints were chanaled into each agency.
#
# Check out this URL for the agencies acronyms
# https://www1.nyc.gov/site/mocs/about/agencies-acronyms-initialisms.page

# %%
data20['Agency'].value_counts()
# Out:
# NYPD     57851
# HPD      32123
# DOT      18268
# DEP      10300
# DCA       9244
# DSNY      7077
# DOB       6323
# DOHMH     4200
# DPR       3952
# TLC       1719
# DHS       1460
# EDC        368
# DOE        218
# DFTA        43
# DOITT       20
# Name: Agency, dtype: int64

# %%
data21['Agency'].value_counts()
# Out:
# NYPD                                     84312
# HPD                                      45077
# DSNY                                     17120
# DOT                                      17066
# DEP                                      12217
# DOB                                       6479
# DPR                                       6330
# DOHMH                                     5443
# EDC                                       3261
# MAYOR'S OFFICE OF SPECIAL ENFORCEMENT     2989
# DCA                                       1524
# DHS                                       1481
# TLC                                       1408
# DOE                                         34
# DOITT                                       20
# DFTA                                        10
# Name: Agency, dtype: int64

# %% [markdown]
# ### Question 2:
#
# - What are some of the differences in patterns we are seeing in which agencies the calls have been channeled to between 2020 and 2021?  Which agencies have been seeing less activity and which ones more?

# %% [markdown]
# So far we worked mainly with Pandas (also some pyplot, numpy and datetime). In addiition to all these liberals Pyhton also has some pretty neat geographical features! Let's check out a few of them on our data:
#
# ## From DataFrame to GeoDataFrame 🧮
#
# GeoDataFrame is a data frame that includes one column with a "special" status. This column is the "geometry" column which enbales Python to refer to the data as geogpraphical. In many cases, like in our case, we will not have the "geometry" column built-in in the data. Instead, we will usually have x any y or Latitue and Longtitude that we will tranform into the needed format.
#
# To go from DataFrame---> GeoDataFrame:
# - we would want to tell python which columns can be used as "geometry".
#
# Note that for point type data a typical geometry columns looks like this
#
#
# - POINT (LON LAT)
#
# The point() format will be created using the GeoDataFrame function. We will only need to tell Python which columns in the data are which (lon, lat).

# %%
#transform data into geo data frame: 


#one geodata frame for 2020 
gdf20 = gpd.GeoDataFrame(
    data20, geometry=gpd.points_from_xy(data20.Longitude, data20.Latitude))

#and another one for 2021 
gdf21 = gpd.GeoDataFrame(
    data21, geometry=gpd.points_from_xy(data21.Longitude, data21.Latitude))

#note that here we tell Python that the column: 
#data20.Longitude is the longtitute and data20.Latitude is the latitude.

# %%
#DataFrame

data20.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    45727718  03/01/2020 12:00:00 AM  03/02/2020 10:37:56 AM  DOHMH
# 1    45730477  03/01/2020 12:00:00 AM  03/02/2020 12:00:01 AM  DOHMH
# 2    45731136  03/01/2020 12:00:00 AM  03/09/2020 12:00:01 AM  DOHMH
# 3    45731855  03/01/2020 12:00:00 AM  03/02/2020 10:19:39 AM  DOHMH
# 4    45728413  03/01/2020 12:00:00 AM  03/02/2020 12:00:01 AM  DOHMH
#
#                                Agency Name  Complaint Type Descriptor  \
# 0  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 1  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 2  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 3  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 4  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
#
#                 Location Type  Incident Zip     Incident Address  ...  \
# 0  Restaurant/Bar/Deli/Bakery       10468.0    2297 CEDAR AVENUE  ...
# 1  Restaurant/Bar/Deli/Bakery       10468.0    2297 CEDAR AVENUE  ...
# 2  Restaurant/Bar/Deli/Bakery       11691.0    20-17 MOTT AVENUE  ...
# 3  Restaurant/Bar/Deli/Bakery       10458.0  2954 WEBSTER AVENUE  ...
# 4  Restaurant/Bar/Deli/Bakery       10128.0        1570 3 AVENUE  ...
#
#   Taxi Company Borough Taxi Pick Up Location Bridge Highway Name  \
# 0                  NaN                   NaN                 NaN
# 1                  NaN                   NaN                 NaN
# 2                  NaN                   NaN                 NaN
# 3                  NaN                   NaN                 NaN
# 4                  NaN                   NaN                 NaN
#
#   Bridge Highway Direction Road Ramp Bridge Highway Segment   Latitude  \
# 0                      NaN       NaN                    NaN  40.862225
# 1                      NaN       NaN                    NaN  40.862225
# 2                      NaN       NaN                    NaN  40.604333
# 3                      NaN       NaN                    NaN  40.867391
# 4                      NaN       NaN                    NaN  40.780279
#
#    Longitude                                 Location  \
# 0 -73.911159  (40.86222535202683, -73.91115884964748)
# 1 -73.911159  (40.86222535202683, -73.91115884964748)
# 2 -73.753038  (40.60433339241671, -73.75303800188094)
# 3 -73.883392  (40.867390857417874, -73.8833918894606)
# 4 -73.952933  (40.78027896232064, -73.95293321926803)
#
#                      geometry
# 0  POINT (-73.91116 40.86223)
# 1  POINT (-73.91116 40.86223)
# 2  POINT (-73.75304 40.60433)
# 3  POINT (-73.88339 40.86739)
# 4  POINT (-73.95293 40.78028)
#
# [5 rows x 42 columns]

# %%
# and GeoDataFrame
#check out our GeoDataFrame--> note the "geometry" column was added (all the way to the right)
gdf20.head(3)
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    45727718  03/01/2020 12:00:00 AM  03/02/2020 10:37:56 AM  DOHMH
# 1    45730477  03/01/2020 12:00:00 AM  03/02/2020 12:00:01 AM  DOHMH
# 2    45731136  03/01/2020 12:00:00 AM  03/09/2020 12:00:01 AM  DOHMH
#
#                                Agency Name  Complaint Type Descriptor  \
# 0  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 1  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 2  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
#
#                 Location Type  Incident Zip   Incident Address  ...  \
# 0  Restaurant/Bar/Deli/Bakery       10468.0  2297 CEDAR AVENUE  ...
# 1  Restaurant/Bar/Deli/Bakery       10468.0  2297 CEDAR AVENUE  ...
# 2  Restaurant/Bar/Deli/Bakery       11691.0  20-17 MOTT AVENUE  ...
#
#   Taxi Company Borough Taxi Pick Up Location Bridge Highway Name  \
# 0                  NaN                   NaN                 NaN
# 1                  NaN                   NaN                 NaN
# 2                  NaN                   NaN                 NaN
#
#   Bridge Highway Direction Road Ramp Bridge Highway Segment   Latitude  \
# 0                      NaN       NaN                    NaN  40.862225
# 1                      NaN       NaN                    NaN  40.862225
# 2                      NaN       NaN                    NaN  40.604333
#
#    Longitude                                 Location  \
# 0 -73.911159  (40.86222535202683, -73.91115884964748)
# 1 -73.911159  (40.86222535202683, -73.91115884964748)
# 2 -73.753038  (40.60433339241671, -73.75303800188094)
#
#                      geometry
# 0  POINT (-73.91116 40.86223)
# 1  POINT (-73.91116 40.86223)
# 2  POINT (-73.75304 40.60433)
#
# [3 rows x 42 columns]

# %%
#check the shape of the data: 

gdf20.shape
# Out:
# (153166, 42)

# %%
gdf21.shape
# Out:
# (204771, 42)

# %% [markdown]
# ## Now we can fianly visualize the data:
#
# First: plot all points for the layer, not I am setting the marker zise on 0.3 since there are so many of them!!

# %%
#plot all 2020 data:
gdf20.plot( color='red',legend=True,figsize=(12, 12),markersize=0.1)
plt.axis('off')
plt.title('311 complaints March 2020')
plt.show()

# %%
#plot all 2020 data: 
gdf21.plot( color='blue',legend=True,figsize=(12, 12),markersize=0.1)
plt.axis('off')
plt.title('311 complaints March 2021')
plt.show()

# %% [markdown]
# # Exmine one agency:
# ### HPD (Housing Preservation & Development)
#
# In order to make better sense of what are people reporting less in these past weeks, we will take a closer look at the different agencies complaints.
#
# We will start with HPD:

# %%
#filter only hpd

hpd20 = gdf20.loc[gdf20['Agency']=='HPD']

hpd21 = gdf21.loc[gdf21['Agency']=='HPD']

# %%
print (len(hpd20))
print (len(hpd21))
# Out:
# 32123
# 45077

# %% [markdown]
# ## Plot HPD data for both 2020 and 2021

# %%
hpd20.plot( color='blue',legend=True,figsize=(12, 12), markersize=1)
plt.axis('off')
plt.title('311 HPD complaints March 2020')
hpd21.plot( color='red',legend=True,figsize=(12, 12),markersize=1)
plt.axis('off')
plt.title('311 HPD complaints March 2021')
plt.show()

# %% [markdown]
# ## Question 3
# Which areas seem to have more or less HPD complaints between March 2020 and March 2021?
#
# ## Another way for us to look into the data is to sub-slice it again:
#
# Now dive into the complaint types in the HPD complaints. So we can learn what are the types of housing complaint we are seeing. that would also help us compare what were some of the changes b/w both periods

# %%
#plot hpd by complaint type:

#1. for 2020
ax = hpd20.plot(column='Complaint Type',legend=True,figsize=(12, 12), alpha = 0.6,markersize=2)
#we can also visualize HPD complaints based on the complaint type: 
plt.title('311 HPD complaints March 2020 by Complaint type')
plt.axis('off')
plt.show()


#2. for 2020 
ax = hpd21.plot(column='Complaint Type',legend=True,figsize=(12, 12),alpha = 0.6,markersize=2)
#we can also visualize HPD complaints based on the complaint type: 
plt.title('311 HPD complaints March 2021 by Complaint type')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Question 4:
#
# What information can we take away from these two maps?

# %% [markdown]
# # Another way to look into the complaint types:
# On top of visualizng the data we can also look into the number of complaints of each type. An easy way to do so is to use the Group.by command. This is a pretty timple command that has a lot of options (more about it on other classes!).
#
# The main thing to know about group.by right now is that group.by operates on a dataframe so that it basically does 3 main things:
#
# 1. Split : take the data and splits it according to the grouping condition
# 2. Apply: calculates what we want it to do: sum, means count etc
# 3. Combine: it combines the data into new groups

# %%
hpd20['Complaint Type'].unique()
# Out:
# array(['HEAT/HOT WATER', 'APPLIANCE', 'WATER LEAK', 'PLUMBING',
#        'PAINT/PLASTER', 'DOOR/WINDOW', 'GENERAL', 'ELECTRIC',
#        'FLOORING/STAIRS', 'UNSANITARY CONDITION', 'SAFETY', 'ELEVATOR',
#        'OUTSIDE BUILDING'], dtype=object)

# %%
len(hpd20)
# Out:
# 32123

# %%
len(hpd21)
# Out:
# 45077

# %% [markdown]
# In our case we will count group by complaint type so that: Python will Split the data according to each type of complaint (hot water, windows etc). Then it will Apply, meaning it would count how many of each compliant type the data has. Finally, Python will Combine the new grouped data. So in our case that would be number of complaints per each complaint type. Note that by doing so, our data frame structure will changes completely so that each row will represent a complaint type, and the data in the cells will be the count of how many of them are there in our data.  All that in one line of code :-)

# %%
#group.by hpd complaints 

#1. for 2019
hpd20_count_type = hpd20.groupby(['Complaint Type']).count()
#1. for 2020
hpd21_count_type = hpd21.groupby(['Complaint Type']).count()

# %%
#look at out new data for 2019 
hpd20_count_type.head(10)
# Out:
#                   Unique Key  Created Date  Closed Date  Agency  Agency Name  \
# Complaint Type
# APPLIANCE                799           799          789     799          799
# DOOR/WINDOW             1517          1517         1502    1517         1517
# ELECTRIC                 996           996          994     996          996
# ELEVATOR                 115           115          115     115          115
# FLOORING/STAIRS          895           895          890     895          895
# GENERAL                 1343          1343         1335    1343         1343
# HEAT/HOT WATER         16344         16344        16314   16344        16344
# OUTSIDE BUILDING          36            36           35      36           36
# PAINT/PLASTER           1970          1970         1958    1970         1970
# PLUMBING                2815          2815         2794    2815         2815
#
#                   Descriptor  Location Type  Incident Zip  Incident Address  \
# Complaint Type
# APPLIANCE                799            799           799               799
# DOOR/WINDOW             1517           1517          1517              1517
# ELECTRIC                 996            996           996               996
# ELEVATOR                 115            115           115               115
# FLOORING/STAIRS          895            895           895               895
# GENERAL                 1343           1343          1343              1343
# HEAT/HOT WATER         16344          16344         16342             16344
# OUTSIDE BUILDING          36             36            36                36
# PAINT/PLASTER           1970           1970          1968              1970
# PLUMBING                2815           2815          2815              2815
#
#                   Street Name  ...  Taxi Company Borough  \
# Complaint Type                 ...
# APPLIANCE                 799  ...                     0
# DOOR/WINDOW              1517  ...                     0
# ELECTRIC                  996  ...                     0
# ELEVATOR                  115  ...                     0
# FLOORING/STAIRS           895  ...                     0
# GENERAL                  1343  ...                     0
# HEAT/HOT WATER          16344  ...                     0
# OUTSIDE BUILDING           36  ...                     0
# PAINT/PLASTER            1970  ...                     0
# PLUMBING                 2815  ...                     0
#
#                   Taxi Pick Up Location  Bridge Highway Name  \
# Complaint Type
# APPLIANCE                             0                    0
# DOOR/WINDOW                           0                    0
# ELECTRIC                              0                    0
# ELEVATOR                              0                    0
# FLOORING/STAIRS                       0                    0
# GENERAL                               0                    0
# HEAT/HOT WATER                        0                    0
# OUTSIDE BUILDING                      0                    0
# PAINT/PLASTER                         0                    0
# PLUMBING                              0                    0
#
#                   Bridge Highway Direction  Road Ramp  Bridge Highway Segment  \
# Complaint Type
# APPLIANCE                                0          0                       0
# DOOR/WINDOW                              0          0                       0
# ELECTRIC                                 0          0                       0
# ELEVATOR                                 0          0                       0
# FLOORING/STAIRS                          0          0                       0
# GENERAL                                  0          0                       0
# HEAT/HOT WATER                           0          0                       0
# OUTSIDE BUILDING                         0          0                       0
# PAINT/PLASTER                            0          0                       0
# PLUMBING                                 0          0                       0
#
#                   Latitude  Longitude  Location  geometry
# Complaint Type
# APPLIANCE              799        799       799       799
# DOOR/WINDOW           1517       1517      1517      1517
# ELECTRIC               996        996       996       996
# ELEVATOR               115        115       115       115
# FLOORING/STAIRS        895        895       895       895
# GENERAL               1343       1343      1343      1343
# HEAT/HOT WATER       16342      16342     16342     16344
# OUTSIDE BUILDING        36         36        36        36
# PAINT/PLASTER         1968       1968      1968      1970
# PLUMBING              2815       2815      2815      2815
#
# [10 rows x 41 columns]

# %%
len(hpd20_count_type)
# Out:
# 13

# %%
#and for 2020
hpd21_count_type.head()
# Out:
#                  Unique Key  Created Date  Closed Date  Agency  Agency Name  \
# Complaint Type
# APPLIANCE              1200          1200          906    1200         1200
# DOOR/WINDOW            2763          2763         2153    2763         2763
# ELECTRIC               1556          1556         1231    1556         1556
# ELEVATOR                146           146           54     146          146
# FLOORING/STAIRS        1813          1813         1485    1813         1813
#
#                  Descriptor  Location Type  Incident Zip  Incident Address  \
# Complaint Type
# APPLIANCE              1200           1200          1199              1200
# DOOR/WINDOW            2763           2763          2763              2763
# ELECTRIC               1556           1556          1554              1556
# ELEVATOR                146            146           146               146
# FLOORING/STAIRS        1813           1813          1813              1813
#
#                  Street Name  ...  Taxi Company Borough  \
# Complaint Type                ...
# APPLIANCE               1200  ...                     0
# DOOR/WINDOW             2763  ...                     0
# ELECTRIC                1556  ...                     0
# ELEVATOR                 146  ...                     0
# FLOORING/STAIRS         1813  ...                     0
#
#                  Taxi Pick Up Location  Bridge Highway Name  \
# Complaint Type
# APPLIANCE                            0                    0
# DOOR/WINDOW                          0                    0
# ELECTRIC                             0                    0
# ELEVATOR                             0                    0
# FLOORING/STAIRS                      0                    0
#
#                  Bridge Highway Direction  Road Ramp  Bridge Highway Segment  \
# Complaint Type
# APPLIANCE                               0          0                       0
# DOOR/WINDOW                             0          0                       0
# ELECTRIC                                0          0                       0
# ELEVATOR                                0          0                       0
# FLOORING/STAIRS                         0          0                       0
#
#                  Latitude  Longitude  Location  geometry
# Complaint Type
# APPLIANCE            1199       1199      1199      1200
# DOOR/WINDOW          2763       2763      2763      2763
# ELECTRIC             1554       1554      1554      1556
# ELEVATOR              146        146       146       146
# FLOORING/STAIRS      1813       1813      1813      1813
#
# [5 rows x 41 columns]

# %%
#because the all columns look the same we will remove them and only keep the first one

hpd20_count_type = hpd20_count_type['Unique Key']
hpd21_count_type = hpd21_count_type['Unique Key']

# %%
hpd20_count_type.head(10)
# Out:
# Complaint Type
# APPLIANCE             799
# DOOR/WINDOW          1517
# ELECTRIC              996
# ELEVATOR              115
# FLOORING/STAIRS       895
# GENERAL              1343
# HEAT/HOT WATER      16344
# OUTSIDE BUILDING       36
# PAINT/PLASTER        1970
# PLUMBING             2815
# Name: Unique Key, dtype: int64

# %%
#now let's see the most common HPD complaints for both March/April 2020 and 2021:

# sort data 

hpd20_count_type = hpd20_count_type.sort_values()

hpd21_count_type = hpd21_count_type.sort_values()

# %%
#5 most common complaints in 2020 were: 
hpd20_count_type.head(5)
# Out:
# Complaint Type
# OUTSIDE BUILDING     36
# ELEVATOR            115
# SAFETY              479
# APPLIANCE           799
# FLOORING/STAIRS     895
# Name: Unique Key, dtype: int64

# %%
#5 most common complaints in 2021  were: 
hpd21_count_type.head(5)
# Out:
# Complaint Type
# OUTSIDE BUILDING      51
# ELEVATOR             146
# SAFETY               547
# APPLIANCE           1200
# ELECTRIC            1556
# Name: Unique Key, dtype: int64

# %% [markdown]
# ## Assignment:
#
# Your turn:
#
# So far we worked on the HPD data.
#
# We will now divide into groups, when each group will look into another agency complaints:
#
# # Group 1: NYPD
# # Group 2: DOT
# # Group 3: DEP
# # Group 4: DSNY
# # Group 5: DOHMH
#
# For each groups:
#
# 1. Please filter the subset of the data that has *YOUR* Agencey name
# 2. Plot, summarize and group.by the data for both 2020 and 2021
#
# Deliver:
# - a. What are the patterns in *YOUR* agency complaints between the 2020 and 2021 data?
# - b. What are some geogrpaphical patterns you are seeing comparing both years?
#
# In class: present your main findings. For you homework: submit your jupyter notebook. In addition on your NYU classes submissions write a short summary of your findings.

# %%
data20 = pd.read_csv('311_March2020.csv')
data21 = pd.read_csv('311_March2021.csv')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (20,31) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
#one geodata frame for 2020 
gdf20 = gpd.GeoDataFrame(
    data20, geometry=gpd.points_from_xy(data20.Longitude, data20.Latitude))

#and another one for 2021 
gdf21 = gpd.GeoDataFrame(
    data21, geometry=gpd.points_from_xy(data21.Longitude, data21.Latitude))

# %%
#your code... 
DOT20 = gdf20.loc[gdf20['Agency']=='DOT']

DOT21 = gdf21.loc[gdf21['Agency']=='DOT']

# %%
print (len(DOT20))
print (len(DOT21))
# Out:
# 18268
# 17066

# %%
DOT20.plot( color='blue',legend=True,figsize=(12, 12), markersize=1)
plt.axis('off')
plt.title('311 DOT complaints March 2020')
DOT21.plot( color='red',legend=True,figsize=(12, 12),markersize=1)
plt.axis('off')
plt.title('311 DOT complaints March 2021')
plt.show()

# %%
#plot DOT by complaint type:

#1. for 2020
ax = DOT20.plot(column='Complaint Type',legend=True,figsize=(12, 12), alpha = 0.6,markersize=2)
#we can also visualize HPD complaints based on the complaint type: 
plt.title('311 DOT complaints March 2020 by Complaint type')
plt.axis('off')
plt.show()


#2. for 2020 
ax = DOT21.plot(column='Complaint Type',legend=True,figsize=(12, 12),alpha = 0.6,markersize=2)
#we can also visualize DOT complaints based on the complaint type: 
plt.title('311 DOT complaints March 2021 by Complaint type')
plt.axis('off')
plt.show()

# %%
DOT20['Complaint Type'].unique()
# Out:
# array(['Street Condition', 'Traffic Signal Condition',
#        'Bus Stop Shelter Placement', 'Street Sign - Dangling',
#        'Street Light Condition', 'Curb Condition',
#        'Street Sign - Damaged', 'Bridge Condition', 'Sidewalk Condition',
#        'Street Sign - Missing', 'Bus Stop Shelter Complaint',
#        'Broken Parking Meter', 'Highway Sign - Damaged',
#        'Highway Condition', 'Ferry Inquiry', 'DEP Street Condition',
#        'Ferry Complaint', 'Bike Rack Condition',
#        'Highway Sign - Dangling', 'Highway Sign - Missing',
#        'Public Toilet', 'Tunnel Condition'], dtype=object)

# %%
len(DOT20)
# Out:
# 18268

# %%
len(DOT21)
# Out:
# 17066

# %%
#group.by DOT complaints 

#1. for 2019
DOT20_count_type = DOT20.groupby(['Complaint Type']).count()
#1. for 2020
DOT21_count_type = DOT21.groupby(['Complaint Type']).count()

# %%
#look at out new data for 2019 
DOT20_count_type.head(10)
# Out:
#                             Unique Key  Created Date  Closed Date  Agency  \
# Complaint Type
# Bike Rack Condition                  9             9            2       9
# Bridge Condition                     8             8            8       8
# Broken Parking Meter               666           666          666     666
# Bus Stop Shelter Complaint          43            43           43      43
# Bus Stop Shelter Placement           9             9            9       9
# Curb Condition                     329           329          329     329
# DEP Street Condition                 9             9            9       9
# Ferry Complaint                     34            34           34      34
# Ferry Inquiry                       11            11           11      11
# Highway Condition                  154           154          153     154
#
#                             Agency Name  Descriptor  Location Type  \
# Complaint Type
# Bike Rack Condition                   9           9              9
# Bridge Condition                      8           8              5
# Broken Parking Meter                666         666            666
# Bus Stop Shelter Complaint           43          43             43
# Bus Stop Shelter Placement            9           9              9
# Curb Condition                      329         329            329
# DEP Street Condition                  9           9              9
# Ferry Complaint                      34          34             34
# Ferry Inquiry                        11          11             11
# Highway Condition                   154         154            154
#
#                             Incident Zip  Incident Address  Street Name  ...  \
# Complaint Type                                                           ...
# Bike Rack Condition                    9                 9            9  ...
# Bridge Condition                       0                 0            0  ...
# Broken Parking Meter                 595               595          595  ...
# Bus Stop Shelter Complaint            43                43           43  ...
# Bus Stop Shelter Placement             9                 9            9  ...
# Curb Condition                       329               329          329  ...
# DEP Street Condition                   9                 9            9  ...
# Ferry Complaint                        0                 0            0  ...
# Ferry Inquiry                          1                 1            1  ...
# Highway Condition                      2                 2            2  ...
#
#                             Taxi Company Borough  Taxi Pick Up Location  \
# Complaint Type
# Bike Rack Condition                            0                      0
# Bridge Condition                               0                      0
# Broken Parking Meter                           0                      0
# Bus Stop Shelter Complaint                     0                      0
# Bus Stop Shelter Placement                     0                      0
# Curb Condition                                 0                      0
# DEP Street Condition                           0                      0
# Ferry Complaint                                0                      0
# Ferry Inquiry                                  0                      0
# Highway Condition                              0                      0
#
#                             Bridge Highway Name  Bridge Highway Direction  \
# Complaint Type
# Bike Rack Condition                           0                         0
# Bridge Condition                              8                         8
# Broken Parking Meter                          0                         0
# Bus Stop Shelter Complaint                    0                         0
# Bus Stop Shelter Placement                    0                         0
# Curb Condition                                0                         0
# DEP Street Condition                          0                         0
# Ferry Complaint                               0                         0
# Ferry Inquiry                                 0                         0
# Highway Condition                           154                       154
#
#                             Road Ramp  Bridge Highway Segment  Latitude  \
# Complaint Type
# Bike Rack Condition                 0                       0         9
# Bridge Condition                    8                       8         0
# Broken Parking Meter                0                       0       588
# Bus Stop Shelter Complaint          0                       0        41
# Bus Stop Shelter Placement          0                       0         9
# Curb Condition                      0                       0       329
# DEP Street Condition                0                       0         9
# Ferry Complaint                     0                       0         0
# Ferry Inquiry                       0                       0         1
# Highway Condition                 154                     154         2
#
#                             Longitude  Location  geometry
# Complaint Type
# Bike Rack Condition                 9         9         9
# Bridge Condition                    0         0         8
# Broken Parking Meter              588       588       666
# Bus Stop Shelter Complaint         41        41        43
# Bus Stop Shelter Placement          9         9         9
# Curb Condition                    329       329       329
# DEP Street Condition                9         9         9
# Ferry Complaint                     0         0        34
# Ferry Inquiry                       1         1        11
# Highway Condition                   2         2       154
#
# [10 rows x 41 columns]

# %%
len(DOT20_count_type)
# Out:
# 22

# %%
#and for 2020
DOT21_count_type.head()
# Out:
#                             Unique Key  Created Date  Closed Date  Agency  \
# Complaint Type
# Bike Rack Condition                 22            22            2      22
# Bridge Condition                    47            47           37      47
# Broken Parking Meter               657           657          657     657
# Bus Stop Shelter Complaint          64            64           57      64
# Bus Stop Shelter Placement          13            13           12      13
#
#                             Agency Name  Descriptor  Location Type  \
# Complaint Type
# Bike Rack Condition                  22          22             22
# Bridge Condition                     47          47             27
# Broken Parking Meter                657         657            657
# Bus Stop Shelter Complaint           64          64             64
# Bus Stop Shelter Placement           13          13             13
#
#                             Incident Zip  Incident Address  Street Name  ...  \
# Complaint Type                                                           ...
# Bike Rack Condition                   22                22           22  ...
# Bridge Condition                       0                 0            0  ...
# Broken Parking Meter                 376               376          376  ...
# Bus Stop Shelter Complaint            64                64           64  ...
# Bus Stop Shelter Placement            13                13           13  ...
#
#                             Taxi Company Borough  Taxi Pick Up Location  \
# Complaint Type
# Bike Rack Condition                            0                      0
# Bridge Condition                               0                      0
# Broken Parking Meter                           0                      0
# Bus Stop Shelter Complaint                     0                      0
# Bus Stop Shelter Placement                     0                      0
#
#                             Bridge Highway Name  Bridge Highway Direction  \
# Complaint Type
# Bike Rack Condition                           0                         0
# Bridge Condition                             47                        47
# Broken Parking Meter                          0                         0
# Bus Stop Shelter Complaint                    0                         0
# Bus Stop Shelter Placement                    0                         0
#
#                             Road Ramp  Bridge Highway Segment  Latitude  \
# Complaint Type
# Bike Rack Condition                 0                       0        22
# Bridge Condition                   47                      47         0
# Broken Parking Meter                0                       0       372
# Bus Stop Shelter Complaint          0                       0        61
# Bus Stop Shelter Placement          0                       0        13
#
#                             Longitude  Location  geometry
# Complaint Type
# Bike Rack Condition                22        22        22
# Bridge Condition                    0         0        47
# Broken Parking Meter              372       372       657
# Bus Stop Shelter Complaint         61        61        64
# Bus Stop Shelter Placement         13        13        13
#
# [5 rows x 41 columns]

# %%
#because the all columns look the same we will remove them and only keep the first one

DOT20_count_type = DOT20_count_type['Unique Key']
DOT21_count_type = DOT21_count_type['Unique Key']

# %%
DOT20_count_type.head(10)
# Out:
# Complaint Type
# Bike Rack Condition             9
# Bridge Condition                8
# Broken Parking Meter          666
# Bus Stop Shelter Complaint     43
# Bus Stop Shelter Placement      9
# Curb Condition                329
# DEP Street Condition            9
# Ferry Complaint                34
# Ferry Inquiry                  11
# Highway Condition             154
# Name: Unique Key, dtype: int64

# %%
#now let's see the most common DOT complaints for both March/April 2020 and 2021:

# sort data 

DOT20_count_type = DOT20_count_type.sort_values()

DOT21_count_type = DOT21_count_type.sort_values()

# %%
#5 most common complaints in 2020 were: 
DOT20_count_type.head(5)
# Out:
# Complaint Type
# Tunnel Condition           1
# Public Toilet              1
# Highway Sign - Dangling    3
# Highway Sign - Missing     6
# Bridge Condition           8
# Name: Unique Key, dtype: int64

# %%
#5 most common complaints in 2021  were: 
DOT21_count_type.head(5)
# Out:
# Complaint Type
# Public Toilet                  1
# Municipal Parking Facility     1
# Highway Sign - Missing         8
# Highway Sign - Damaged         8
# Highway Sign - Dangling       10
# Name: Unique Key, dtype: int64
